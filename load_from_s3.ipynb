# %% [markdown]
# # Read from S3 buckets

# %%
import xarray as xr

# %%
bucket_location = "s3://coiled-test-data-synthetic-seismic/synthetic_volume/"

# %%
remote_data = xr.open_zarr(
    store=bucket_location
)

# %%
remote_data
# Out:
# <xarray.Dataset>
# Dimensions:            (bin_no: 3000, depth: 1259, track_no: 3000)
# Coordinates:
#   * bin_no             (bin_no) uint32 1000 1001 1002 1003 ... 3997 3998 4000
#   * depth              (depth) float32 0.0 3.975 7.949 ... 4.996e+03 5e+03
#   * track_no           (track_no) uint32 1000 1001 1002 1003 ... 3997 3998 4000
# Data variables:
#     synthetic_seismic  (track_no, bin_no, depth) float16 dask.array<chunksize=(300, 300, 745), meta=np.ndarray>
