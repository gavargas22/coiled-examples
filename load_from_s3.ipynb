# %% [markdown]
# # Read from S3 buckets

# %%
import xarray as xr

# %%
bucket_location = "s3://nova-scotia-gavargas"

# %%
remote_data = xr.open_zarr(
    store=bucket_location
)

# %%
remote_data
# Out:
# <xarray.Dataset>
# Dimensions:  (iline: 595, xline: 476, twt: 1501)
# Coordinates:
#   * iline    (iline) uint16 1003 1004 1005 1006 1007 ... 1594 1595 1596 1597
#   * twt      (twt) float64 0.0 4.0 8.0 12.0 ... 5.992e+03 5.996e+03 6e+03
#   * xline    (xline) uint16 1003 1004 1005 1006 1007 ... 1475 1476 1477 1478
# Data variables:
#     data     (iline, xline, twt) float32 dask.array<chunksize=(75, 60, 188), meta=np.ndarray>
# Attributes:
#     coord_scalar:        -10.0
#     measurement_system:  m
#     percentiles:         [-1.5735211245699187e-13, -1.5076269468287669e-13, -...
#     sample_rate:         4.0
#     source_file:         CQI-tAngs.sgy
#     text:                C 1 Nova Socotia Deptarment of Energy ¦ Penobscot 3D...
